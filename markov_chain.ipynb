# %%
import numpy as np
import matplotlib as plt

def target_distribution(x):
    # standard normal distribution (mean 0, variance 1)
    return np.exp(-0.5 * x**2) / (np.sqrt(2 * np.pi))

def proposal_distribuution(x_prev, step_size=1.0):
    # uniform proposal distribution centered around x_prev with width 'step_size'
    return x_prev + np.random.uniform(-step_size, step_size)

def metropolis_hanstings(num_samples, burn_in=1000, step_size=1.0):
    samples = np.zero(num_samples + burn_in)
